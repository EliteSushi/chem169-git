# %% [markdown]
# <a href="https://colab.research.google.com/github/EliteSushi/chem169-git/blob/main/R007_Github_Basics_Colab_Version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

repo_path = '/content/chem169-git/'
file_path = os.path.join(repo_path, 'notes.txt')

# Create the file and write a line of text
with open(file_path, 'w') as f:
    f.write('This is a note from Google Colab.\n')
